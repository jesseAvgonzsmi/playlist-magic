# %%
from lyricsgenius import Genius
import pandas as pd

genius = Genius('ED27Q3X4pYpWCNEgOL2m2a6ouOlLgW0Fnq9aUFf2jdCk57zgCcO4VRM4clqz6ZTH')

# %%
lib = pd.read_csv('library.csv')
lib.head(5)
# Out:
#                          track.trackName         track.artistName  \
# 0                          Sweet Ophelia                Zella Day
# 1  Hazy Shade of Winter (feat. Ray Toro)               Gerard Way
# 2                       Stuck in My Ways  Five Finger Death Punch
# 3                    Cradle to the Grave  Five Finger Death Punch
# 4                            Coming Down  Five Finger Death Punch
#
#                          track.trackUri                track.id
# 0  spotify:track:1jPZgfC9tWFNf7iBGdrTPV  1jPZgfC9tWFNf7iBGdrTPV
# 1  spotify:track:1tBZnhDT8xbgJTs43FiqrD  1tBZnhDT8xbgJTs43FiqrD
# 2  spotify:track:224wA4Sh6Q1i7nH2w1nOnr  224wA4Sh6Q1i7nH2w1nOnr
# 3  spotify:track:2pxCVKnYzmVIQJONukyBrU  2pxCVKnYzmVIQJONukyBrU
# 4  spotify:track:3OrTQrydMdfQeQJtPXBNSx  3OrTQrydMdfQeQJtPXBNSx

# %%
import time
from requests.exceptions import Timeout

def get_lyrics(song, artist, retries=5):
    for i in range(retries):
        try:
            response = genius.search_song(song, artist)
            if response is None or response.lyrics == "Specified song does not contain lyrics. Rejecting.":
                print(f"No lyrics found for {song} by {artist}")
                return "No Lyrics"
            return response.lyrics
        except Timeout:
            if i < retries - 1: 
                time.sleep(1)
                continue
            else:
                raise

# %%
# lyrics = pd.DataFrame(columns=['artist', 'song', 'lyrics'])
# lyrics['artist'] = lib['track.artistName']
# lyrics['song'] = lib['track.trackName']

# #for each row in lyrics, get the lyrics
# for index, row in lyrics.iterrows():
#     song_lyrics = get_lyrics(row['song'], row['artist'])
#     lyrics.loc[index, 'lyrics'] = song_lyrics

# lyrics.head(20)
# Out:
# Searching for "Sweet Ophelia" by Zella Day...
# Done.
# Searching for "Hazy Shade of Winter (feat. Ray Toro)" by Gerard Way...
# Done.
# Searching for "Stuck in My Ways" by Five Finger Death Punch...
# Done.
# Searching for "Cradle to the Grave" by Five Finger Death Punch...
# Done.
# Searching for "Coming Down" by Five Finger Death Punch...
# Done.
# Searching for "Canto 34" by Five Finger Death Punch...
# Specified song does not contain lyrics. Rejecting.
# No lyrics found for Canto 34 by Five Finger Death Punch
# Searching for "The Ballad of Mona Lisa" by Panic! At The Disco...
# Done.
# Searching for "Oh Fortuna - Carmina Burana - VIP Mix" by Timmy Trumpet...
# No results found for: 'Oh Fortuna - Carmina Burana - VIP Mix Timmy Trumpet'
# No lyrics found for Oh Fortuna - Carmina Burana - VIP Mix by Timmy Trumpet
# Searching for "Hard To See" by Five Finger Death Punch...
# Done.
# Searching for "Get Out Alive" by Three Days Grace...
# Done.
# Searching for "Ori Ori" by Manntra...
# ...

# %%
lyrics = pd.read_csv('lyrics.csv')

# %%
import re

def extract_lyrics(text):
    start = text.find("\n") + len("\n")
    return text[start:].strip()

def clean_lyrics(text):
    if text.count(" - ") > 5:
        return None  # Drop the text
    text = re.sub(r'\[.*?\]', '', text)  # Remove anything inside []
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = text.replace("Embed","")
    return text.replace("\n", " ")

lyrics['lyrics'] = lyrics['lyrics'].apply(extract_lyrics)
lyrics['lyrics'] = lyrics['lyrics'].apply(clean_lyrics)
lyrics.head(5)
# Out:
#                     artist                                   song  \
# 0                Zella Day                          Sweet Ophelia
# 1               Gerard Way  Hazy Shade of Winter (feat. Ray Toro)
# 2  Five Finger Death Punch                       Stuck in My Ways
# 3  Five Finger Death Punch                    Cradle to the Grave
# 4  Five Finger Death Punch                            Coming Down
#
#                                               lyrics
# 0  Believe me now, you're too young, girl Cherry ...
# 1  Time, time, time See what's become of me   Tim...
# 2  All the shades of gray that loom inside me No ...
# 3  The blood that runs within my veins (The blood...
# 4  It's caving in around me What I thought was so...

# %%
lyrics.to_csv('lyrics.csv', index=False)
